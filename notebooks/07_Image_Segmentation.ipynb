# %% [markdown]
# # 07 Image Segmentation

# %% [markdown]
# ## 匯入套件

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %% [markdown]
# ## 取得 Oxford-IIIT Pets 資料集

# %%
dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)
# Out:
# Downloading and preparing dataset 773.52 MiB (download: 773.52 MiB, generated: 774.69 MiB, total: 1.51 GiB) to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incompleteDULDW2/oxford_iiit_pet-train.tfrecord*...:…
# Generating test examples...:   0%|          | 0/3669 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incompleteDULDW2/oxford_iiit_pet-test.tfrecord*...: …
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0. Subsequent calls will reuse this data.

# %% [markdown]
# ## 正規化

# %% [markdown]
# ## 讀取影像

# %% [markdown]
# ## 定義超參數

# %% [markdown]
# ## 讀取影像

# %% [markdown]
# ## 資料擴增

# %% [markdown]
# ## 資料批次化

# %% [markdown]
# ## 顯示影像

# %% [markdown]
# ## 建立模型

# %%
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step

# %% [markdown]
# ### 上採樣

# %% [markdown]
# ### 建置 UNet Model

# %% [markdown]
# ## 訓練模型

# %% [markdown]
# ### 繪製模型圖

# %% [markdown]
# ### 繪製預測 Mask

# %%
# Out:
# 1/1 [==============================] - 12s 12s/step

# %%
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Sample Prediction after epoch 20
#
# 57/57 [==============================] - 13s 224ms/step - loss: 0.1648 - accuracy: 0.9326 - val_loss: 0.2951 - val_accuracy: 0.9001

# %%
# Out:
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 62ms/step
